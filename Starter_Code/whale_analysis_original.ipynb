# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_csv = Path("Resources/whale_returns.csv")
# YOUR CODE HERE
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
# YOUR CODE HERE
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
# YOUR CODE HERE
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_csv = Path("Resources/algo_returns.csv")
# YOUR CODE HERE
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
# YOUR CODE HERE
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
# YOUR CODE HERE
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_csv = Path("Resources/sp500_history.csv")
# YOUR CODE HERE
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
# YOUR CODE HERE
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
# YOUR CODE HERE
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
# YOUR CODE HERE
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop nulls
# YOUR CODE HERE
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %%
# Rename Column
# YOUR CODE HERE
# Out:
#              S&P 500
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
# YOUR CODE HERE
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# 2015-03-06 -0.011460 -0.003929
# 2015-03-09  0.001303  0.017254

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns.

# %%
# Plot daily returns
# YOUR CODE HERE

# %%
# Plot cumulative returns
# YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# ## Performance by Month and Year
#
# Analyze the performance by Month and Year:
#
# 1. Calculate the Annual Returns
# 2. Sort the 2017 portfolio returns in descending order to determine the best portfolios for 2017
# 3. Calculate the Monthly Returns
# 4. Sort in descending order, the porfolio returns for December 2018

# %%
# Returns by Year
# YOUR CODE HERE
# Out:
#       SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Year
# 2015                  -0.001755           -0.018798
# 2016                   0.006357           -0.113786
# 2017                   0.139174           -0.083763
# 2018                  -0.155639           -0.124487
# 2019                   0.184567            0.076191
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# Year
# 2015                     0.028154                0.041279  0.235785 -0.064872
# 2016                     0.285932               -0.074570  0.169710  0.130114
# 2017                    -0.004449                0.479395 -0.010532  0.151736
# 2018                    -0.314504               -0.154322  0.164383 -0.155967
# 2019                    -0.052145                0.288971  0.093575  0.189086
#
#        S&P 500
# Year
# 2015  0.042665
# 2016 -0.106793
# 2017 -0.157674
# 2018  0.080887
# 2019 -0.165591

# %%
# Top Portfolio returns for 2017
# YOUR CODE HERE
# Out:
# BERKSHIRE HATHAWAY INC         0.479395
# Algo 2                         0.151736
# SOROS FUND MANAGEMENT LLC      0.139174
# TIGER GLOBAL MANAGEMENT LLC   -0.004449
# Algo 1                        -0.010532
# PAULSON & CO.INC.             -0.083763
# S&P 500                       -0.157674
# Name: 2017, dtype: float64

# %%
# Returns by Month
# YOUR CODE HERE
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Year Month
# 2015 3                       0.018496            0.016368
#      4                       0.002327            0.016717
#      5                       0.002031            0.017202
#      6                      -0.022387           -0.011315
#      7                      -0.013433           -0.020351
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Year Month
# 2015 3                         0.009920                0.008938  0.014758
#      4                         0.012399                0.015854 -0.004224
#      5                        -0.007884               -0.008566  0.004221
#      6                        -0.023955               -0.023044  0.003256
#      7                         0.014274               -0.020391 -0.044059
#
#               Algo 2   S&P 500
# Year Month
# 2015 3     -0.000012  0.018857
#      4      0.006595 -0.019604
#      5     -0.002336  0.001307
#      6     -0.010888  0.015490
#      7     -0.019254 -0.010133

# %%
# Top Portfolio Returns for December 2018
# YOUR CODE HERE
# Out:
# S&P 500                        0.075708
# Algo 1                        -0.059361
# PAULSON & CO.INC.             -0.091802
# SOROS FUND MANAGEMENT LLC     -0.097825
# BERKSHIRE HATHAWAY INC        -0.110173
# Algo 2                        -0.127480
# TIGER GLOBAL MANAGEMENT LLC   -0.148269
# Name: (2018, 12), dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk
# YOUR CODE HERE

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. Which portfolios are riskier than the S&P 500?
# YOUR CODE HERE
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# S&P 500                        0.008587
# dtype: float64

# %%
# Determine which portfolios are riskier than the S&P 500
# YOUR CODE HERE
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# S&P 500                        False
# dtype: bool

# %%
# Calculate the annualized standard deviation (252 trading days)
# YOUR CODE HERE
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# S&P 500                        0.136313
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&PP 500 using a 21 day window
# 2. Calcualte the correlation between each stock to determine which portfolios may mimick the S&P 500
# 2. Calculate and plot a 60 day Beta for Berkshire Hathaway Inc compared to the S&&P 500

# %%
# Calculate and plot the rolling standard deviation for the S&PP 500 using a 21 day window
# YOUR CODE HERE

# %%
# Correlation
# YOUR CODE HERE
# Out:
# <style  type="text/css" >
#     #T_f9f8309e_7416_11e9_b3df_685b35983e01row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row0_col1 {
#             background-color:  #b2d866;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row0_col2 {
#             background-color:  #8fc766;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row0_col3 {
#             background-color:  #c1e066;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row0_col4 {
#             background-color:  #57ab66;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row0_col5 {
#             background-color:  #d3e966;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row0_col6 {
#             background-color:  #088466;
#             color:  #f1f1f1;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row1_col0 {
#             background-color:  #b3d966;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row1_col2 {
#             background-color:  #6fb766;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row1_col3 {
#             background-color:  #8dc666;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row1_col4 {
#             background-color:  #4aa466;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row1_col5 {
#             background-color:  #add666;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row1_col6 {
#             background-color:  #0b8566;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row2_col0 {
#             background-color:  #8fc766;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row2_col1 {
#             background-color:  #6db666;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row2_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row2_col3 {
#             background-color:  #6eb666;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row2_col4 {
#             background-color:  #319866;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row2_col5 {
#             background-color:  #82c066;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row2_col6 {
#             background-color:  #088466;
#             color:  #f1f1f1;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row3_col0 {
#             background-color:  #c1e066;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row3_col1 {
#             background-color:  #8ac466;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row3_col2 {
#             background-color:  #6cb666;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row3_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row3_col4 {
#             background-color:  #50a866;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row3_col5 {
#             background-color:  #b0d866;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row3_col6 {
#             background-color:  #048266;
#             color:  #f1f1f1;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row4_col0 {
#             background-color:  #52a866;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row4_col1 {
#             background-color:  #42a066;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row4_col2 {
#             background-color:  #2a9466;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row4_col3 {
#             background-color:  #4da666;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row4_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row4_col5 {
#             background-color:  #4aa466;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row4_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row5_col0 {
#             background-color:  #d3e966;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row5_col1 {
#             background-color:  #acd666;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row5_col2 {
#             background-color:  #82c066;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row5_col3 {
#             background-color:  #b1d866;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row5_col4 {
#             background-color:  #4fa766;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row5_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row5_col6 {
#             background-color:  #078366;
#             color:  #f1f1f1;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row6_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row6_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row6_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row6_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row6_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row6_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f9f8309e_7416_11e9_b3df_685b35983e01row6_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_f9f8309e_7416_11e9_b3df_685b35983e01" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SOROS FUND MANAGEMENT LLC</th>        <th class="col_heading level0 col1" >PAULSON & CO.INC. </th>        <th class="col_heading level0 col2" >TIGER GLOBAL MANAGEMENT LLC</th>        <th class="col_heading level0 col3" >BERKSHIRE HATHAWAY INC</th>        <th class="col_heading level0 col4" >Algo 1</th>        <th class="col_heading level0 col5" >Algo 2</th>        <th class="col_heading level0 col6" >S&P 500</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f9f8309e_7416_11e9_b3df_685b35983e01level0_row0" class="row_heading level0 row0" >SOROS FUND MANAGEMENT LLC</th>
#                         <td id="T_f9f8309e_7416_11e9_b3df_685b35983e01row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_f9f8309e_7416_11e9_b3df_685b35983e01row0_col1" class="data row0 col1" >0.699823</td>
#                         <td id="T_f9f8309e_7416_11e9_b3df_685b35983e01row0_col2" class="data row0 col2" >0.56104</td>
#                         <td id="T_f9f8309e_7416_11e9_b3df_685b35983e01row0_col3" class="data row0 col3" >0.754157</td>
#                         <td id="T_f9f8309e_7416_11e9_b3df_685b35983e01row0_col4" class="data row0 col4" >0.320901</td>
#                         <td id="T_f9f8309e_7416_11e9_b3df_685b35983e01row0_col5" class="data row0 col5

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# YOUR CODE HERE

# %% [markdown]
# ### Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rollwing window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the `ewm` with a 21 day half-life.

# %%
# (OPTIONAL) YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# Calculate and plot the annualized Sharpe ratios for all portfolios to determine which portfolio has the best performance

# %%
# Annualzied Sharpe Ratios
# YOUR CODE HERE
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# S&P 500                       -0.518582
# dtype: float64

# %% [markdown]
#  plot() these sharpe ratios using a barplot.
#  On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales?

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
# YOUR CODE HERE
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40

# %%
# Read the second stock
# YOUR CODE HERE
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75

# %%
# Read the third stock
# YOUR CODE HERE
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62

# %%
# Concatenate all stocks into a single DataFrame
# YOUR CODE HERE
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40

# %%
# Reset the index
# YOUR CODE HERE
# Out:
#   Trade DATE Symbol     NOCP
# 0 2019-05-09   GOOG  1162.38
# 1 2019-05-08   GOOG  1166.27
# 2 2019-05-07   GOOG  1174.10
# 3 2019-05-06   GOOG  1189.39
# 4 2019-05-03   GOOG  1185.40

# %%
# Pivot the Data so that the stock tickers are the columns, the dates are the index, and the 
# values are the closing prices
# YOUR CODE HERE
# Out:
# Symbol        AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
# Drop Nulls
# YOUR CODE HERE
# Out:
# Symbol          AAPL      COST      GOOG
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio return
weights = [1/3, 1/3, 1/3]
# YOUR CODE HERE
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# YOUR CODE HERE
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-15                     0.000398               -0.010492 -0.004331
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
#
#               Algo 2   S&P 500    Custom
# Date
# 2019-04-15 -0.004572 -0.000509  0.007522
# 2019-04-16  0.002899  0.002279  0.000340
# 2019-04-17 -0.005228 -0.001577  0.009292
# 2019-04-18 -0.001229 -0.001011  0.001545
# 2019-04-22 -0.001936 -0.008764  0.001217

# %%
# Only compare dates where the new, custom portfolio has dates
# YOUR CODE HERE

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
# YOUR CODE HERE
# Out:
# SOROS FUND MANAGEMENT LLC      0.146812
# PAULSON & CO.INC.              0.116928
# TIGER GLOBAL MANAGEMENT LLC    0.232898
# BERKSHIRE HATHAWAY INC         0.247305
# Algo 1                         0.133927
# Algo 2                         0.139499
# S&P 500                        0.152469
# Custom                         0.211627
# dtype: float64

# %%
# Rolling
# YOUR CODE HERE

# %%
# Beta
# YOUR CODE HERE

# %%
# Annualzied Sharpe Ratios
# YOUR CODE HERE
# Out:
# SOROS FUND MANAGEMENT LLC      0.380007
# PAULSON & CO.INC.              0.227577
# TIGER GLOBAL MANAGEMENT LLC   -1.066635
# BERKSHIRE HATHAWAY INC         0.103006
# Algo 1                         2.001260
# Algo 2                         0.007334
# S&P 500                       -0.427676
# Custom                         0.876152
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE

# %% [markdown]
# ## Include correlation analysis to determine which stocks (if any) are correlated

# %%
# YOUR CODE HERE
# Out:
# <style  type="text/css" >
#     #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row0_col1 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row0_col2 {
#             background-color:  #79bc66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row0_col3 {
#             background-color:  #d2e866;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row0_col4 {
#             background-color:  #5faf66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row0_col5 {
#             background-color:  #deee66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row0_col6 {
#             background-color:  #078366;
#             color:  #f1f1f1;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row0_col7 {
#             background-color:  #bbdd66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row1_col0 {
#             background-color:  #cce666;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row1_col2 {
#             background-color:  #7bbd66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row1_col3 {
#             background-color:  #a9d466;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row1_col4 {
#             background-color:  #64b266;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row1_col5 {
#             background-color:  #cae466;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row1_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row1_col7 {
#             background-color:  #a4d266;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row2_col0 {
#             background-color:  #7ebe66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row2_col1 {
#             background-color:  #83c166;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row2_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row2_col3 {
#             background-color:  #59ac66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row2_col4 {
#             background-color:  #289366;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row2_col5 {
#             background-color:  #6eb666;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row2_col6 {
#             background-color:  #0f8766;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row2_col7 {
#             background-color:  #63b166;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row3_col0 {
#             background-color:  #d2e866;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row3_col1 {
#             background-color:  #abd566;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row3_col2 {
#             background-color:  #51a866;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row3_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row3_col4 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row3_col5 {
#             background-color:  #cae466;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row3_col6 {
#             background-color:  #058266;
#             color:  #f1f1f1;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row3_col7 {
#             background-color:  #cce666;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row4_col0 {
#             background-color:  #5aac66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row4_col1 {
#             background-color:  #65b266;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row4_col2 {
#             background-color:  #1b8d66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row4_col3 {
#             background-color:  #59ac66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row4_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row4_col5 {
#             background-color:  #63b166;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row4_col6 {
#             background-color:  #018066;
#             color:  #f1f1f1;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row4_col7 {
#             background-color:  #41a066;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row5_col0 {
#             background-color:  #ddee66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row5_col1 {
#             background-color:  #cbe566;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row5_col2 {
#             background-color:  #67b366;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row5_col3 {
#             background-color:  #cae466;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row5_col4 {
#             background-color:  #65b266;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row5_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row5_col6 {
#             background-color:  #048266;
#             color:  #f1f1f1;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row5_col7 {
#             background-color:  #bcde66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row6_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row6_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row6_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row6_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row6_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row6_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row6_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row6_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row7_col0 {
#             background-color:  #bdde66;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row7_col1 {
#             background-color:  #a9d466;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row7_col2 {
#             background-color:  #63b166;
#             color:  #000000;
#         }    #T_fb0f3dd8_7416_11e9_88cc_685b35983e01row7_col3 {
#             background-color:  #cee666;
#             color:  #000000;
